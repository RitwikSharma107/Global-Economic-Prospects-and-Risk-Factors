# %%
import numpy as np
import pandas as pd
import os
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf 
from statsmodels.tsa.seasonal import seasonal_decompose 
#from pmdarima import auto_arima                        
from sklearn.metrics import mean_squared_error
from statsmodels.tools.eval_measures import rmse
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
country_to_predict="India"

# %% [markdown]
# **ARIMA**

# %%
df=pd.read_excel('test_arima.xlsx')
df['Year']=pd.to_datetime(df.Year, format="%Y")
df=df[(df['Country']==country_to_predict)]
df.index.freq = 'YS'
df.head()
# Out:
#           Year   Value Country
# 147 1970-01-01  47.737   India
# 148 1971-01-01  48.398   India
# 149 1972-01-01  49.061   India
# 150 1973-01-01  49.722   India
# 151 1974-01-01  50.374   India

# %%
del df["Country"]

# %%
df['Year']=pd.to_datetime(df['Year'], format="%Y")
df=df.set_index(['Year'])
df.head()
df.index.freq = 'YS'

# %%
train_df = df[:len(df)-6]
test_df = df[len(df)-6:]

# %%
plt.figure(figsize=(20,10))
plt.xlabel("Year")
plt.ylabel("Value")
plt.plot(df)

# %%
rolmean=train_df.rolling(window=6).mean()
rolstd=train_df.rolling(window=6).std()
print(rolmean.head(15))
print(rolstd.head(15))
# Out:
#                 Value
# Year
# 1970-01-01        NaN
# 1971-01-01        NaN
# 1972-01-01        NaN
# 1973-01-01        NaN
# 1974-01-01        NaN
# 1975-01-01  49.384000
# 1976-01-01  50.032833
# 1977-01-01  50.670167
# 1978-01-01  51.291000
# 1979-01-01  51.890500
# 1980-01-01  52.463833
# 1981-01-01  53.006500
# 1982-01-01  53.515833
# 1983-01-01  53.991167
# 1984-01-01  54.433667
#                Value
# Year
# 1970-01-01       NaN
# 1971-01-01       NaN
# 1972-01-01       NaN
# 1973-01-01       NaN
# 1974-01-01       NaN
# 1975-01-01  1.227507
# 1976-01-01  1.211599
# 1977-01-01  1.185113
# 1978-01-01  1.148669
# 1979-01-01  1.103795
# 1980-01-01  1.050679
# 1981-01-01  0.989940
# 1982-01-01  0.924051
# 1983-01-01  0.856456
# 1984-01-01  0.792759

# %%
plt.figure(figsize=(20,10))
actual=plt.plot(train_df, color='red', label='Actual')
mean_6=plt.plot(rolmean, color='green', label='Rolling Mean') 
std_6=plt.plot(rolstd, color='black', label='Rolling Std')
plt.legend(loc='best')
plt.title('Rolling Mean & Standard Deviation')
plt.show(block=False)

# %%
from statsmodels.tsa.stattools import adfuller
print('Dickey-Fuller Test: ')
dftest=adfuller(train_df['Value'], autolag='AIC')
dfoutput=pd.Series(dftest[0:4], index=['Test Statistic','p-value','Lags Used','No. of Obs'])
for key,value in dftest[4].items():
    dfoutput['Critical Value (%s)'%key] = value
print(dfoutput)
# Out:
# Dickey-Fuller Test:
# Test Statistic          -5.285269
# p-value                  0.000006
# Lags Used                2.000000
# No. of Obs              40.000000
# Critical Value (1%)     -3.605565
# Critical Value (5%)     -2.937069
# Critical Value (10%)    -2.606986
# dtype: float64

# %%
plt.figure(figsize=(20,10))
df_log=np.log(train_df)
plt.plot(df_log)

# %%
plt.figure(figsize=(20,10))
MAvg=df_log.rolling(window=6).mean()
MStd=df_log.rolling(window=6).std()
plt.plot(df_log)
plt.plot(MAvg, color='blue')

# %%
df_log_diff=df_log-MAvg
df_log_diff.head(12)
# Out:
#                Value
# Year
# 1970-01-01       NaN
# 1971-01-01       NaN
# 1972-01-01       NaN
# 1973-01-01       NaN
# 1974-01-01       NaN
# 1975-01-01  0.032692
# 1976-01-01  0.031668
# 1977-01-01  0.030395
# 1978-01-01  0.028940
# 1979-01-01  0.027346
# 1980-01-01  0.025577
# 1981-01-01  0.023666

# %%
df_log_diff=df_log_diff.dropna()
df_log_diff.head()
# Out:
#                Value
# Year
# 1975-01-01  0.032692
# 1976-01-01  0.031668
# 1977-01-01  0.030395
# 1978-01-01  0.028940
# 1979-01-01  0.027346

# %%
def stationarity(timeseries):
    
    rolmean=timeseries.rolling(window=6).mean()
    rolstd=timeseries.rolling(window=6).std()
    
    plt.figure(figsize=(20,10))
    actual=plt.plot(timeseries, color='red', label='Actual')
    mean_6=plt.plot(rolmean, color='green', label='Rolling Mean') 
    std_6=plt.plot(rolstd, color='black', label='Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)
    
    print('Dickey-Fuller Test: ')
    dftest=adfuller(timeseries['Value'], autolag='AIC')
    dfoutput=pd.Series(dftest[0:4], index=['Test Statistic','p-value','Lags Used','No. of Obs'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput)

# %%
stationarity(df_log_diff)
# Out:
# Dickey-Fuller Test:
# Test Statistic          -3.168229
# p-value                  0.021899
# Lags Used                2.000000
# No. of Obs              35.000000
# Critical Value (1%)     -3.632743
# Critical Value (5%)     -2.948510
# Critical Value (10%)    -2.613017
# dtype: float64

# %%
plt.figure(figsize=(20,10))
exp_df=df_log.ewm(halflife=12, min_periods=0, adjust=True).mean()
plt.plot(df_log)
plt.plot(exp_df, color='black')

# %%
exp_df_diff=df_log-exp_df
stationarity(exp_df_diff)
# Out:
# Dickey-Fuller Test:
# Test Statistic          -2.712360
# p-value                  0.071924
# Lags Used                3.000000
# No. of Obs              39.000000
# Critical Value (1%)     -3.610400
# Critical Value (5%)     -2.939109
# Critical Value (10%)    -2.608063
# dtype: float64

# %%
plt.figure(figsize=(20,10))
df_shift=df_log-df_log.shift(2)
plt.plot(df_shift)

# %%
df_shift=df_shift.dropna()
stationarity(df_shift)
# Out:
# Dickey-Fuller Test:
# Test Statistic          -1.397525
# p-value                  0.583462
# Lags Used                8.000000
# No. of Obs              32.000000
# Critical Value (1%)     -3.653520
# Critical Value (5%)     -2.957219
# Critical Value (10%)    -2.617588
# dtype: float64

# %%
from statsmodels.tsa.stattools import acf, pacf

lag_acf=acf(train_df, nlags=20)
lag_pacf=pacf(train_df, nlags=20, method='ols')

plt.figure(figsize=(20,10))
plt.subplot(121)
plt.plot(lag_acf)
plt.axhline(y=0,linestyle='--',color='green')
plt.axhline(y=-1.96/np.sqrt(len(df_shift)),linestyle='--',color='green')
plt.axhline(y=1.96/np.sqrt(len(df_shift)),linestyle='--',color='green')
plt.title('Autocorrelation Function')

plt.subplot(122)
plt.plot(lag_pacf)
plt.axhline(y=0,linestyle='--',color='green')
plt.axhline(y=-1.96/np.sqrt(len(df_shift)),linestyle='--',color='green')
plt.axhline(y=1.96/np.sqrt(len(df_shift)),linestyle='--',color='green')
plt.title('Partial Autocorrelation Function')
# Out:
# Text(0.5, 1.0, 'Partial Autocorrelation Function')

# %%
from statsmodels.tsa.arima_model import ARIMA

plt.figure(figsize=(20,10))
model=ARIMA(df_log, order=(2,2,1))
results=model.fit(disp=-1)
plt.plot(train_df)
plt.plot(results.fittedvalues, color='red')
plt.title('RSS: %.4f'% sum((results.fittedvalues-df_shift['Value'])**2))
print('plotting ARIMA model')
# Out:
# plotting ARIMA model

# %%
predictions=pd.Series(results.fittedvalues, copy=True)
print(predictions.head())
# Out:
# Year
# 1972-01-01   -0.000196
# 1973-01-01   -0.000149
# 1974-01-01   -0.000285
# 1975-01-01   -0.000441
# 1976-01-01   -0.000496
# Freq: AS-JAN, dtype: float64

# %%
predictions_cum_sum=predictions.cumsum()
print(predictions_cum_sum.head())
# Out:
# Year
# 1972-01-01   -0.000196
# 1973-01-01   -0.000345
# 1974-01-01   -0.000629
# 1975-01-01   -0.001071
# 1976-01-01   -0.001567
# Freq: AS-JAN, dtype: float64

# %%
predictions_log=pd.Series(df_log['Value'].iloc[0], index=df_log.index)
predictions_log=predictions_log.add(predictions_cum_sum,fill_value=0)
#predictions_log.head()

# %%
arima_pred = results.predict(start = len(train_df), end = len(df)-1, typ="levels").rename("ARIMA Predictions")
arima_pred=np.exp(arima_pred)
test_df['ARIMA_Predictions'] = arima_pred
#arima_pred

# %%
test_df['Value'].plot(figsize = (16,5), legend=True)
arima_pred.plot(legend = True);

# %%
arima_rmse_error = rmse(test_df['Value'], arima_pred)
arima_mse_error = arima_rmse_error**2
mean_value = df['Value'].mean()

print(f'MSE Error: {arima_mse_error}\nRMSE Error: {arima_rmse_error}\nMean: {mean_value}')
# Out:
# MSE Error: 0.002762105911074942
# RMSE Error: 0.05255574099063719
# Mean: 59.587183673469404

# %%
output=results.forecast(13)
output1=np.exp(output[0])
output1
outputs = pd.DataFrame(output1[-7:])
outputs.index=['2019', '2020', '2021','2022', '2023', '2024',"2025"]
outputs["Country"]=country_to_predict
outputs
# Out:
#               0 Country
# 2019  69.493523   India
# 2020  69.660076   India
# 2021  69.816400   India
# 2022  69.968508   India
# 2023  70.121037   India
# 2024  70.276880   India
# 2025  70.437033   India

# %%
import pandas
from openpyxl import load_workbook

book = load_workbook('test_arima.xlsx')
writer = pandas.ExcelWriter('test_arima.xlsx', engine='openpyxl')
writer.book = book
writer.sheets = {ws.title: ws for ws in book.worksheets}

for sheetname in writer.sheets:
    outputs.to_excel(writer,sheet_name=sheetname, startrow=writer.sheets[sheetname].max_row, index = True,header= False)

writer.save()

# %%
test_df
# Out:
#              Value  ARIMA_Predictions
# Year
# 2013-01-01  67.931          67.930035
# 2014-01-01  68.286          68.279578
# 2015-01-01  68.607          68.590916
# 2016-01-01  68.897          68.864208
# 2017-01-01  69.165          69.102237
# 2018-01-01  69.416          69.309900

# %% [markdown]
# **LSTM**

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
df=pd.read_excel('test_lstm.xlsx')
df['Year']=pd.to_datetime(df.Year, format="%Y")
df=df[(df['Country']==country_to_predict)]
del df["Country"]
df['Year']=pd.to_datetime(df['Year'], format="%Y")
df=df.set_index(['Year'])
df.index.freq = 'YS'
train_df_lstm = df[:len(df)-6]
test_df_lstm = df[len(df)-6:]
df.tail()
# Out:
#              Value
# Year
# 2014-01-01  68.286
# 2015-01-01  68.607
# 2016-01-01  68.897
# 2017-01-01  69.165
# 2018-01-01  69.416

# %%
scaler.fit(train_df)
scaled_train_data = scaler.transform(train_df_lstm)
scaled_test_data = scaler.transform(test_df_lstm)

# %%
from keras.preprocessing.sequence import TimeseriesGenerator

n_input = 1
n_features= 1
generator = TimeseriesGenerator(scaled_train_data, scaled_train_data, length=n_input, batch_size=1)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM

lstm_model = Sequential()
lstm_model.add(LSTM(64, activation='relu', input_shape=(n_input, n_features)))
lstm_model.add(Dense(1))
lstm_model.compile(optimizer='adam', loss='mse')

lstm_model.summary()
# Out:
# Model: "sequential_24"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_24 (LSTM)               (None, 64)                16896
# _________________________________________________________________
# dense_24 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 16,961
# Trainable params: 16,961
# Non-trainable params: 0
# _________________________________________________________________

# %%
lstm_model.fit_generator(generator,epochs=20)
# Out:
# Epoch 1/20
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2964
# Epoch 2/20
# 42/42 [==============================] - 0s 2ms/step - loss: 0.1794
# Epoch 3/20
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0850
# Epoch 4/20
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0363
# Epoch 5/20
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0232
# Epoch 6/20
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0198
# Epoch 7/20
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0178
# Epoch 8/20
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0159
# Epoch 9/20
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0142
# Epoch 10/20
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0122
# Epoch 11/20
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0105
# Epoch 12/20
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0092
# Epoch 13/20
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0075
# Epoch 14/20
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 15/20
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0050
# Epoch 16/20
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0040
# Epoch 17/20
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0032
# Epoch 18/20
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0025
# Epoch 19/20
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0019
# Epoch 20/20
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0014

# %%
losses_lstm = lstm_model.history.history['loss']
plt.figure(figsize=(12,4))
plt.xticks(np.arange(0,21,1))
plt.plot(range(len(losses_lstm)),losses_lstm);

# %%
lstm_predictions_scaled = list()

batch = scaled_train_data[-n_input:]
current_batch = batch.reshape((1, n_input, n_features))

for i in range(len(test_df)):   
    lstm_pred = lstm_model.predict(current_batch)[0]
    lstm_predictions_scaled.append(lstm_pred) 
    current_batch = np.append(current_batch[:,1:,:],[[lstm_pred]],axis=1)

# %%
lstm_predictions_scaled
# Out:
# [array([1.0124749], dtype=float32),
#  array([1.0258522], dtype=float32),
#  array([1.0402659], dtype=float32),
#  array([1.0558416], dtype=float32),
#  array([1.0727015], dtype=float32),
#  array([1.0910603], dtype=float32)]

# %%
lstm_predictions = scaler.inverse_transform(lstm_predictions_scaled)

# %%
lstm_predictions
# Out:
# array([[67.79210271],
#        [68.05708044],
#        [68.3425873 ],
#        [68.65110972],
#        [68.9850704 ],
#        [69.34872204]])

# %%
test_df['LSTM_Predictions'] = lstm_predictions

# %%
test_df
# Out:
#              Value  ARIMA_Predictions  LSTM_Predictions
# Year
# 2013-01-01  67.931          67.930035         67.792103
# 2014-01-01  68.286          68.279578         68.057080
# 2015-01-01  68.607          68.590916         68.342587
# 2016-01-01  68.897          68.864208         68.651110
# 2017-01-01  69.165          69.102237         68.985070
# 2018-01-01  69.416          69.309900         69.348722

# %%
test_df['Value'].plot(figsize = (16,5), legend=True)
test_df['LSTM_Predictions'].plot(legend = True);

# %%
lstm_rmse_error = rmse(test_df['Value'], test_df["LSTM_Predictions"])
lstm_mse_error = lstm_rmse_error**2
mean_value = df['Value'].mean()

print(f'MSE Error: {lstm_mse_error}\nRMSE Error: {lstm_rmse_error}\nMean: {mean_value}')
# Out:
# MSE Error: 0.039828951344465076
# RMSE Error: 0.19957192023043993
# Mean: 59.587183673469404

# %%
lstm_predictions_scaled = list()

batch = scaled_train_data[-n_input:]
current_batch = batch.reshape((1, n_input, n_features))

for i in range(len(test_df)+6):   
    lstm_pred = lstm_model.predict(current_batch)[0]
    lstm_predictions_scaled.append(lstm_pred) 
    current_batch = np.append(current_batch[:,1:,:],[[lstm_pred]],axis=1)

# %%
lstm_predictions_scaled
# Out:
# [array([1.0124749], dtype=float32),
#  array([1.0258522], dtype=float32),
#  array([1.0402659], dtype=float32),
#  array([1.0558416], dtype=float32),
#  array([1.0727015], dtype=float32),
#  array([1.0910603], dtype=float32),
#  array([1.1111802], dtype=float32),
#  array([1.1333839], dtype=float32),
#  array([1.1580741], dtype=float32),
#  array([1.1857595], dtype=float32),
#  array([1.217037], dtype=float32),
#  array([1.252739], dtype=float32)]

# %%
lstm_predictions = scaler.inverse_transform(lstm_predictions_scaled)

# %%
lstm_predictions
# Out:
# array([[67.79210271],
#        [68.05708044],
#        [68.3425873 ],
#        [68.65110972],
#        [68.9850704 ],
#        [69.34872204],
#        [69.74725713],
#        [70.1870677 ],
#        [70.67613258],
#        [71.22452505],
#        [71.84406815],
#        [72.55125317]])

# %%
output2=lstm_predictions
outputs2 = pd.DataFrame(lstm_predictions[-7:])
outputs2.index=['2019', '2020', '2021','2022', '2023', '2024',"2025"]
outputs2["Country"]=country_to_predict
outputs2
# Out:
#               0 Country
# 2019  69.348722   India
# 2020  69.747257   India
# 2021  70.187068   India
# 2022  70.676133   India
# 2023  71.224525   India
# 2024  71.844068   India
# 2025  72.551253   India

# %%
import pandas
from openpyxl import load_workbook

book = load_workbook('test_lstm.xlsx')
writer = pandas.ExcelWriter('test_lstm.xlsx', engine='openpyxl')
writer.book = book
writer.sheets = {ws.title: ws for ws in book.worksheets}

for sheetname in writer.sheets:
    outputs2.to_excel(writer,sheet_name=sheetname, startrow=writer.sheets[sheetname].max_row, index = True,header= False)

writer.save()

# %% [markdown]
# **Prophet**

# %%
df = pd.read_excel('test_prophet.xlsx')
df=df[(df['Country']==country_to_predict)]
del df["Country"]
df.head()
df_pr = df.copy()
#df = df.reset_index()
df_pr.columns = ['ds','y']
df_pr.tail()
# Out:
#        ds       y
# 191  2014  68.286
# 192  2015  68.607
# 193  2016  68.897
# 194  2017  69.165
# 195  2018  69.416

# %%
df_pr['ds'] = pd.to_datetime(df_pr['ds'],format="%Y")
df_pr.tail()
# Out:
#             ds       y
# 191 2014-01-01  68.286
# 192 2015-01-01  68.607
# 193 2016-01-01  68.897
# 194 2017-01-01  69.165
# 195 2018-01-01  69.416

# %%
train_data_pr = df_pr.iloc[:len(df)-6]
test_data_pr = df_pr.iloc[len(df)-6:]

# %%
from fbprophet import Prophet

# %%
m = Prophet()
m.fit(train_data_pr)
future = m.make_future_dataframe(periods=6,freq='YS')
prophet_pred = m.predict(future)
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
prophet_pred.tail()
# Out:
#            ds      trend  ...  multiplicative_terms_upper       yhat
# 44 2014-01-01  23.317686  ...                         0.0  68.397806
# 45 2015-01-01  23.748999  ...                         0.0  68.838422
# 46 2016-01-01  24.180312  ...                         0.0  69.268687
# 47 2017-01-01  24.612806  ...                         0.0  69.691480
# 48 2018-01-01  25.044119  ...                         0.0  70.124239
#
# [5 rows x 16 columns]

# %%
prophet_pred = pd.DataFrame({"Year" : prophet_pred[-6:]['ds'], "Pred" : prophet_pred[-6:]["yhat"]})

# %%
prophet_pred = prophet_pred.set_index("Year")

# %%
prophet_pred.index.freq = "YS"

# %%
prophet_pred
# Out:
#                  Pred
# Year
# 2013-01-01  67.965047
# 2014-01-01  68.397806
# 2015-01-01  68.838422
# 2016-01-01  69.268687
# 2017-01-01  69.691480
# 2018-01-01  70.124239

# %%
test_df["Prophet_Predictions"] = prophet_pred['Pred'].values
test_df
# Out:
#              Value  ARIMA_Predictions  LSTM_Predictions  Prophet_Predictions
# Year
# 2013-01-01  67.931          67.930035         67.792103            67.965047
# 2014-01-01  68.286          68.279578         68.057080            68.397806
# 2015-01-01  68.607          68.590916         68.342587            68.838422
# 2016-01-01  68.897          68.864208         68.651110            69.268687
# 2017-01-01  69.165          69.102237         68.985070            69.691480
# 2018-01-01  69.416          69.309900         69.348722            70.124239

# %%
import seaborn as sns

# %%
plt.figure(figsize=(16,5))
ax = sns.lineplot(x= test_df.index, y=test_df["Value"])
sns.lineplot(x=test_df.index, y = test_df["Prophet_Predictions"]);

# %%
prophet_rmse_error = rmse(test_df['Value'], test_df["Prophet_Predictions"])
prophet_mse_error = prophet_rmse_error**2
mean_value = df['Value'].mean()

print(f'MSE Error: {prophet_mse_error}\nRMSE Error: {prophet_rmse_error}\nMean: {mean_value}')
# Out:
# MSE Error: 0.16402520280642874
# RMSE Error: 0.4050002503782297
# Mean: 59.587183673469404

# %%
future = m.make_future_dataframe(periods=13,freq = 'YS')
prophet_pred = m.predict(future)

# %%
#prophet_pred = pd.DataFrame({"Year" : prophet_pred[-11:]['ds'], "Pred" : prophet_pred[-11:]["yhat"]})
abc=prophet_pred[['ds', 'yhat']].tail(7)

# %%
abc.index=['2019', '2020', '2021','2022', '2023', '2024',"2025"]
del abc['ds']
abc = abc.rename(columns={'yhat': 'Value'})
abc["Country"]=country_to_predict
abc
# Out:
#           Value Country
# 2019  70.564855   India
# 2020  70.995120   India
# 2021  71.417914   India
# 2022  71.850672   India
# 2023  72.291288   India
# 2024  72.721553   India
# 2025  73.144347   India

# %%
import pandas
from openpyxl import load_workbook

book = load_workbook('test_prophet.xlsx')
writer = pandas.ExcelWriter('test_prophet.xlsx', engine='openpyxl')
writer.book = book
writer.sheets = {ws.title: ws for ws in book.worksheets}

for sheetname in writer.sheets:
    abc.to_excel(writer,sheet_name=sheetname, startrow=writer.sheets[sheetname].max_row, index = True,header= False)

writer.save()

# %%
rmse_errors = [arima_rmse_error, lstm_rmse_error, prophet_rmse_error]
mse_errors = [arima_mse_error, lstm_mse_error, prophet_mse_error]
errors = pd.DataFrame({"Models" : ["ARIMA", "LSTM", "Prophet"],"RMSE Errors" : rmse_errors, "MSE Errors" : mse_errors})

# %%
print(f"Mean: {test_df['Value'].mean()}")
errors
errors.plot(kind="bar",x="Models",y="MSE Errors")
errors.plot(kind="bar",x="Models",y="RMSE Errors")
# Out:
# Mean: 68.717

# %%
errors["Country"]=country_to_predict
errors
# Out:
#     Models  RMSE Errors  MSE Errors Country
# 0    ARIMA     0.052556    0.002762   India
# 1     LSTM     0.199572    0.039829   India
# 2  Prophet     0.405000    0.164025   India

# %%
import pandas
from openpyxl import load_workbook

book = load_workbook('errors.xlsx')
writer = pandas.ExcelWriter('errors.xlsx', engine='openpyxl')
writer.book = book
writer.sheets = {ws.title: ws for ws in book.worksheets}

for sheetname in writer.sheets:
    errors.to_excel(writer,sheet_name=sheetname, startrow=writer.sheets[sheetname].max_row, index =False,header= False)

writer.save()

# %%
output3=test_df
output3["Country"]=country_to_predict
output3.reset_index()
output3.index=['2013', '2014', '2015','2016', '2017', '2018']
output3
# Out:
#        Value  ARIMA_Predictions  LSTM_Predictions  Prophet_Predictions Country
# 2013  67.931          67.930035         67.792103            67.965047   India
# 2014  68.286          68.279578         68.057080            68.397806   India
# 2015  68.607          68.590916         68.342587            68.838422   India
# 2016  68.897          68.864208         68.651110            69.268687   India
# 2017  69.165          69.102237         68.985070            69.691480   India
# 2018  69.416          69.309900         69.348722            70.124239   India

# %%
import pandas
from openpyxl import load_workbook

book = load_workbook('comparison.xlsx')
writer = pandas.ExcelWriter('comparison.xlsx', engine='openpyxl')
writer.book = book
writer.sheets = {ws.title: ws for ws in book.worksheets}

for sheetname in writer.sheets:
    output3.to_excel(writer,sheet_name=sheetname, startrow=writer.sheets[sheetname].max_row, index =True,header= False)

writer.save()

# %%
plt.figure(figsize=(19,9))
test_df.plot(figsize=(19,9))
